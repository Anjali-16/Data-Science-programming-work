# %% [markdown]
# ## Tutorial 1 - Autoencoder
#
# In this example, we will use an autoencoder to 'learn' to recrate hand written digits.

# %%
import numpy as np

# %% [markdown]
# ### Load and normalize our data

# %%
from tensorflow.keras.datasets import mnist


# load MNIST data
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
print(train_images.shape)
print(test_images.shape)

# Flatten the images for a autoencoder input (28x28 is 784 -- therfore, input is 784 neurons)
train_images = np.reshape(train_images, (-1, 784))
test_images = np.reshape(test_images, (-1, 784))
print(train_images.shape)
print(test_images.shape)

# Normalize data - since it's grayscale, we can divide by 255 to get each pixel between 0 and 1
train_images = train_images.astype('float32') / 255
test_images = test_images.astype('float32') / 255
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 784)
# (10000, 784)

# %%
from matplotlib import pyplot as plt

n = 10
plt.figure(figsize=(9, 2))
for i in range(n):
  ax = plt.subplot(1, n, i+1)
  plt.imshow(test_images[i].reshape(28, 28), cmap="gray")
  ax.axis('off')

plt.show()

# %% [markdown]
# ### Create an autoencoder model.

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential

input_dim = 28*28
latent_vec_len = 6 # this is the 'bottleneck' of the autoencoder

# Define the autoencoder architecture
# build the encoder
autoencoder = Sequential()
autoencoder.add(Input(shape=(input_dim,)))
autoencoder.add(Dense(500, activation='relu'))
autoencoder.add(Dense(300, activation='relu'))
autoencoder.add(Dense(100, activation='relu'))

# the bottleneck layer
autoencoder.add(Dense(latent_vec_len, activation='relu'))

# the decoder layer
autoencoder.add(Dense(100, activation='relu'))
autoencoder.add(Dense(300, activation='relu'))
autoencoder.add(Dense(500, activation='relu'))
autoencoder.add(Dense(input_dim, activation='sigmoid'))

# Compile the autoencoder model
autoencoder.compile(loss='binary_crossentropy', optimizer='adam')

# Get summary
autoencoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 500)               392500
#
#  dense_25 (Dense)            (None, 300)               150300
#
#  dense_26 (Dense)            (None, 100)               30100
#
#  dense_27 (Dense)            (None, 6)                 606
#
#  dense_28 (Dense)            (None, 100)               700
#
#  dense_29 (Dense)            (None, 300)               30300
#
#  dense_30 (Dense)            (None, 500)               150500
#
#  dense_31 (Dense)            (None, 784)               392784
#
# =================================================================
# Total params: 1,147,790
# Trainable params: 1,147,790
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the autoencoder model.

# %%
from tensorflow.keras.callbacks import EarlyStopping # EarlyStopping during model training


# Train the autoencoder with MNIST data
early_stop = EarlyStopping(monitor='loss', patience=3, verbose=1)
history = autoencoder.fit(
    x=train_images, # For autoencoders, both the input and the target are the same
    y=train_images, 
    epochs=10, 
    batch_size=128,
    shuffle=True, 
    validation_data=(test_images, test_images),
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 469/469 [==============================] - 19s 36ms/step - loss: 0.2101 - val_loss: 0.1695
# Epoch 2/10
# 469/469 [==============================] - 18s 39ms/step - loss: 0.1634 - val_loss: 0.1585
# Epoch 3/10
# 469/469 [==============================] - 17s 37ms/step - loss: 0.1558 - val_loss: 0.1537
# Epoch 4/10
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1516 - val_loss: 0.1502
# Epoch 5/10
# 469/469 [==============================] - 16s 35ms/step - loss: 0.1485 - val_loss: 0.1478
# Epoch 6/10
# 469/469 [==============================] - 17s 36ms/step - loss: 0.1462 - val_loss: 0.1467
# Epoch 7/10
# 469/469 [==============================] - 16s 35ms/step - loss: 0.1444 - val_loss: 0.1445
# Epoch 8/10
# 469/469 [==============================] - 18s 37ms/step - loss: 0.1427 - val_loss: 0.1433
# Epoch 9/10
# 469/469 [==============================] - 19s 40ms/step - loss: 0.1414 - val_loss: 0.1426
# Epoch 10/10
# 469/469 [==============================] - 19s 41ms/step - loss: 0.1401 - val_loss: 0.1416

# %%
# Plot training and validation loss scores
# against the number of epochs.
import matplotlib.pyplot as plt
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.ylabel('Binary Cross Entropy Loss')
plt.xlabel('Epoch')
plt.title('Autoencoder Reconstruction Loss', pad=13)
plt.legend(loc='upper right')

# %% [markdown]
# ### Test the autoencoder model by reconstructing the test images and visually inspecting the results.

# %%
reconstructed_images = autoencoder.predict(test_images)

images = []
for i in range(100):
    images.append(test_images[i].reshape(28,28))
    images.append(reconstructed_images[i].reshape(28,28))
rows = 10
cols = 10
plt.figure(figsize=(10,10))
for i in range(rows*cols):
    plt.subplot(rows,cols,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    if (i%2 == 0):
        plt.imshow(images[i],cmap='gray')
    else:
        plt.imshow(images[i])
plt.show()
# Out:
# 313/313 [==============================] - 2s 6ms/step

# %% [markdown]
# ### Save the autoencoder for later user.

# %%
autoencoder.save('initially_trained_autoencoder.h5')

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# But what happens if we sent it something it has been trained on? Let’s try it out:

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image


####################################
# load a sample image
image = tf.keras.utils.load_img('/content/drive/My Drive/testimg02.png', target_size=(28, 28), color_mode = "grayscale")


####################################
# predict an image from this sample
input_arr = tf.keras.utils.img_to_array(image)
input_arr = input_arr/ 255 # normalize between 0 and 1
input_arr = input_arr.reshape(784)
input_arr = np.array([input_arr])  # Convert single image to a batch with one image in it

predictions = autoencoder.predict(input_arr)
print(predictions.shape)


#####################################
# display the two images side by side
# 
plt.subplot(1,2,1)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(image, cmap="gray")


plt.subplot(1,2,2)
plt.xticks([])
plt.yticks([])
plt.grid(False)
plt.imshow(predictions[0].reshape(28,28), cmap="gray")


plt.show()
# Out:
# 1/1 [==============================] - 0s 22ms/step
# (1, 784)

# %% [markdown]
# ### Summary
#
# Since the new image wasn't part of the original training dataset, it's seen as an 'anomoly' by the autoencoder. This is indicated by the difference (error) betweem the original image and the reconstructed image.

# %% [markdown]
# ## Analysis:
# 1. Firstly as per the question asked in in class task i changed the bottle neck layer neurons value to 6 and run the model.
# 2. So as per the results i observed that the error value got increased from 0.019 to 0.14.
# 3. If i observed the image it looks like A letter . (For 6 bottle neck neurons)
# 4. For 16 neurons it ok not that much clear.
# 5. For 100 neurons as you asked i tried then the image so irrelevant . It is over fitting for data.
# 6 On the whole i conclude that  increasing the number of neurons in the bottleneck layer also increases the complexity of the network, which can lead to overfitting to the training data and slower training times.
# 7. If the number of neurons in the bottleneck layer is decreased, the compression of the input data will be more aggressive, which can result in a loss of information during the encoding process. This can lead to a decrease in the accuracy of the reconstructed data.
